# %% [markdown]
# ### 티처블머신
# 1. 모델 및 라벨 불러오기
#
# - Load the model
# > ### model = load_model("./converted_keras/keras_Model.h5", compile=False)
#
# - Load the labels
# > ### class_names = open("./converted_keras/labels.txt", "r").readlines()
#
#
# 2. 새로운 이미지로 테스트함
# > #### #Replace this with the path to your image
# > ### image = Image.open('./tmp.jpg')
#
# #### !pip install tensorflow

# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("./converted_keras/keras_Model.h5", compile=False)
class_names = open("./converted_keras/labels.txt", "r").readlines()

file_list=glob('./face/*.jpg')

for file in file_list:

    img=Image.open(file).resize((224,224))
    image_array=np.array(img)
    normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1
    
    data= normalized_image_array.reshape(1,224,224,3)
    prediction = model.predict(data)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]
    # Print prediction and confidence score
    print("Class:", class_name[2:], end="")
    print("Confidence Score:", confidence_score)

    # Print prediction and confidence score
    plt.imshow(img)
    plt.show()
    print("Class:", class_name[2:], end="")
    print("Confidence Score:", confidence_score)
# Out:
# Class: female
# Confidence Score: 0.86784035
# Class: female
# Confidence Score: 0.86784035
# Class: female
# Confidence Score: 0.96327984
# Class: female
# Confidence Score: 0.96327984
# Class: male
# Confidence Score: 0.8147434
# Class: male
# Confidence Score: 0.8147434
# Class: female
# Confidence Score: 0.8400859
# Class: female
# Confidence Score: 0.8400859
# Class: male
# Confidence Score: 0.78810096
# Class: male
# Confidence Score: 0.78810096
# Class: female
# Confidence Score: 0.52667826
# Class: female
# Confidence Score: 0.52667826
# Class: male
# Confidence Score: 0.8931946
# Class: male
# Confidence Score: 0.8931946
# Class: female
# Confidence Score: 0.9349821
# Class: female
# Confidence Score: 0.9349821
# Class: male
# Confidence Score: 0.79309195
# Class: male
# Confidence Score: 0.79309195
# Class: male
# Confidence Score: 0.76724523
# Class: male
# Confidence Score: 0.76724523
# Class: male
# Confidence Score: 0.7026711
# Class: male
# Confidence Score: 0.7026711

# %%
print(image)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x27B5DC5B340>

# %%
image.show()
